# %%
import pandas as pd
import scipy

# %%
pwd
# Out:
# 'C:\\Users\\patry\\Desktop\\technopol-ai'

# %%
df = pd.read_csv('data/train_data.csv', error_bad_lines = False)
# Out:
# C:\Users\patry\AppData\Local\Temp\ipykernel_21996\2705250927.py:1: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv('data/train_data.csv', error_bad_lines = False)
# b'Skipping line 5856: expected 40 fields, saw 70\nSkipping line 7939: expected 40 fields, saw 49\n'

# %%
df[['TAXCLASS']].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='TAXCLASS'>

# %%
df_tax = df[(df['TAXCLASS'] == '1')]

# %%
df_tax[['BORO']].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='BORO'>

# %%
import matplotlib.pyplot as plt

# %%
df_tax = df[(df['TAXCLASS'] == '1') & (df['BORO'] == 1)]

# %%
df_tax.count()
# Out:
# BBLE                        35
# BORO                        35
# BLOCK                       35
# LOT                         35
# EASEMENT                     0
# OWNER                       35
# BLDGCL                      35
# TAXCLASS                    35
# LTFRONT                     35
# LTDEPTH                     35
# EXT                         10
# STORIES                     35
# FULLVAL                     35
# AVLAND                      35
# AVTOT                       35
# EXLAND                      35
# EXTOT                       35
# EXCD1                       13
# STADDR                      35
# POSTCODE                    35
# EXMPTCL                      0
# BLDFRONT                    35
# BLDDEPTH                    35
# AVLAND2                      0
# AVTOT2                       0
# EXLAND2                      0
# EXTOT2                       0
# EXCD2                        1
# PERIOD                      35
# YEAR                        35
# ...

# %%
continuos_data_1 = df_tax [['FULLVAL','LTFRONT', 'LTDEPTH', 'STORIES', 'AVLAND', 'AVTOT', 'EXLAND', 'EXTOT', 'BLDFRONT', 'BLDDEPTH', 'AVLAND2', 'AVTOT2', 'EXLAND2', 'EXTOT2', 'Latitude', 'Longitude' ]]

# %%
categorical_data = df[['BORO', 'BLOCK', 'LOT', 'EASEMENT', 'BLDGCL', 'TAXCLASS', 'EXT', 'STADDR', 'POSTCODE', 'EXMPTCL', 'EXCD2', 'YEAR', 'VALTYPE', 'Community Board', 'Council District', 'Census Tract', 'BIN', 'NTA', ]]

# %%
continuos_data = df [['FULLVAL','LTFRONT', 'LTDEPTH', 'STORIES', 'AVLAND', 'AVTOT', 'EXLAND', 'EXTOT', 'BLDFRONT', 'BLDDEPTH', 'AVLAND2', 'AVTOT2', 'EXLAND2', 'EXTOT2', 'Latitude', 'Longitude' ]]

# %%
predicted_data = df [['FULLVAL']]

# %% [markdown]
# # BORO 1

# %%
correlation = continuos_data_1.corr(method="pearson");

# %%
correlation['FULLVAL']
# Out:
# FULLVAL      1.000000
# LTFRONT     -0.023544
# LTDEPTH     -0.419185
# STORIES      0.536564
# AVLAND       0.756044
# AVTOT        0.952277
# EXLAND      -0.272361
# EXTOT       -0.265193
# BLDFRONT     0.493373
# BLDDEPTH     0.297382
# AVLAND2           NaN
# AVTOT2            NaN
# EXLAND2           NaN
# EXTOT2            NaN
# Latitude    -0.946059
# Longitude   -0.948712
# Name: FULLVAL, dtype: float64

# %%
 df_tax[['FULLVAL']]
# Out:
#        FULLVAL
# 7943    607000
# 7945    432000
# 7946    550000
# 7947    604000
# 7949    404000
# ...        ...
# 11939   501000
# 11941   407000
# 11943   298000
# 11944   459000
# 11945   557000
#
# [2510 rows x 1 columns]

# %%
plt.scatter(df_tax[['AVTOT']].to_numpy(), df_tax[['FULLVAL']].to_numpy())

# %%
df_tax = df_tax[df_tax['FULLVAL'] < 25000000]

# %%
plt.scatter(df_tax[['STORIES']].to_numpy(), df_tax[['FULLVAL']].to_numpy())

# %%
plt.scatter(df_tax[['AVLAND']].to_numpy(), df_tax[['FULLVAL']].to_numpy())

# %%
plt.scatter(df_tax[['Latitude']].to_numpy(), df_tax[['FULLVAL']].to_numpy())

# %% [markdown]
# # BORO 2

# %%
df_tax = df[(df['TAXCLASS'] == '1') & (df['BORO'] == 2)]
df_tax.count()
continuos_data_1 = df_tax [['FULLVAL','LTFRONT', 'LTDEPTH', 'STORIES', 'AVLAND', 'AVTOT', 'EXLAND', 'EXTOT', 'BLDFRONT', 'BLDDEPTH', 'AVLAND2', 'AVTOT2', 'EXLAND2', 'EXTOT2', 'Latitude', 'Longitude' ]]

# %%
correlation = continuos_data_1.corr(method="pearson")
correlation['FULLVAL']
# Out:
# FULLVAL      1.000000
# LTFRONT      0.716314
# LTDEPTH      0.341645
# STORIES     -0.069890
# AVLAND       0.607516
# AVTOT        0.857421
# EXLAND      -0.021496
# EXTOT       -0.004166
# BLDFRONT     0.608097
# BLDDEPTH    -0.018603
# AVLAND2           NaN
# AVTOT2            NaN
# EXLAND2           NaN
# EXTOT2            NaN
# Latitude     0.535543
# Longitude    0.071638
# Name: FULLVAL, dtype: float64

# %%
plt.scatter(df_tax[['AVTOT']].to_numpy(), df_tax[['FULLVAL']].to_numpy())

# %%
plt.scatter(df_tax[['BLDFRONT']].to_numpy(), df_tax[['FULLVAL']].to_numpy())

# %%
plt.scatter(df_tax[['LTFRONT']].to_numpy(), df_tax[['FULLVAL']].to_numpy())

# %%
plt.scatter(df_tax[['Latitude']].to_numpy(), df_tax[['FULLVAL']].to_numpy())

# %% [markdown]
# # BORO 3

# %%
df_tax = df[(df['TAXCLASS'] == '1') & (df['BORO'] == 3)]
df_tax.count()
continuos_data_1 = df_tax [['FULLVAL','LTFRONT', 'LTDEPTH', 'STORIES', 'AVLAND', 'AVTOT', 'EXLAND', 'EXTOT', 'BLDFRONT', 'BLDDEPTH', 'AVLAND2', 'AVTOT2', 'EXLAND2', 'EXTOT2', 'Latitude', 'Longitude' ]]

# %%
correlation = continuos_data_1.corr(method="pearson")
correlation['FULLVAL']
# Out:
# FULLVAL      1.000000
# LTFRONT      0.146504
# LTDEPTH     -0.019929
# STORIES      0.429803
# AVLAND       0.381946
# AVTOT        0.708129
# EXLAND       0.012689
# EXTOT        0.063431
# BLDFRONT     0.234980
# BLDDEPTH    -0.028929
# AVLAND2           NaN
# AVTOT2            NaN
# EXLAND2           NaN
# EXTOT2            NaN
# Latitude     0.696876
# Longitude    0.411086
# Name: FULLVAL, dtype: float64

# %%
plt.scatter(df_tax[['Latitude']].to_numpy(), df_tax[['FULLVAL']].to_numpy())

# %%
plt.scatter(df_tax[['Longitude']].to_numpy(), df_tax[['FULLVAL']].to_numpy())

# %% [markdown]
# # BORO 4

# %%
df_tax = df[(df['TAXCLASS'] == '1') & (df['BORO'] == 4)]
df_tax.count()
continuos_data_1 = df_tax [['FULLVAL','LTFRONT', 'LTDEPTH', 'STORIES', 'AVLAND', 'AVTOT', 'EXLAND', 'EXTOT', 'BLDFRONT', 'BLDDEPTH', 'AVLAND2', 'AVTOT2', 'EXLAND2', 'EXTOT2', 'Latitude', 'Longitude' ]]

# %%
correlation = continuos_data_1.corr(method="pearson")
correlation['FULLVAL']
# Out:
# FULLVAL      1.000000
# LTFRONT      0.556766
# LTDEPTH      0.282592
# STORIES     -0.021223
# AVLAND       0.384763
# AVTOT        0.868122
# EXLAND       0.050015
# EXTOT        0.092784
# BLDFRONT     0.560789
# BLDDEPTH     0.236253
# AVLAND2           NaN
# AVTOT2            NaN
# EXLAND2           NaN
# EXTOT2            NaN
# Latitude     0.514654
# Longitude    0.319065
# Name: FULLVAL, dtype: float64

# %%
plt.scatter(df_tax[['AVTOT']].to_numpy(), df_tax[['FULLVAL']].to_numpy())

# %%
plt.scatter(df_tax[['LTFRONT']].to_numpy(), df_tax[['FULLVAL']].to_numpy())

# %%
plt.scatter(df_tax[['BLDFRONT']].to_numpy(), df_tax[['FULLVAL']].to_numpy())

# %%
plt.scatter(df_tax[['Latitude']].to_numpy(), df_tax[['FULLVAL']].to_numpy())

# %% [markdown]
# # BORO 5

# %%
df_tax = df[(df['TAXCLASS'] == '1') & (df['BORO'] == 4)]
df_tax.count()
continuos_data_1 = df_tax [['FULLVAL','LTFRONT', 'LTDEPTH', 'STORIES', 'AVLAND', 'AVTOT', 'EXLAND', 'EXTOT', 'BLDFRONT', 'BLDDEPTH', 'AVLAND2', 'AVTOT2', 'EXLAND2', 'EXTOT2', 'Latitude', 'Longitude' ]]

# %%
correlation = continuos_data_1.corr(method="pearson")
correlation['FULLVAL']
# Out:
# FULLVAL      1.000000
# LTFRONT      0.556766
# LTDEPTH      0.282592
# STORIES     -0.021223
# AVLAND       0.384763
# AVTOT        0.868122
# EXLAND       0.050015
# EXTOT        0.092784
# BLDFRONT     0.560789
# BLDDEPTH     0.236253
# AVLAND2           NaN
# AVTOT2            NaN
# EXLAND2           NaN
# EXTOT2            NaN
# Latitude     0.514654
# Longitude    0.319065
# Name: FULLVAL, dtype: float64

# %%
plt.scatter(df_tax[['AVTOT']].to_numpy(), df_tax[['FULLVAL']].to_numpy())

# %%
plt.scatter(df_tax[['LTFRONT']].to_numpy(), df_tax[['FULLVAL']].to_numpy())

# %%
plt.scatter(df_tax[['BLDFRONT']].to_numpy(), df_tax[['FULLVAL']].to_numpy())

# %%
plt.scatter(df_tax[['Latitude']].to_numpy(), df_tax[['FULLVAL']].to_numpy())

# %%
continuos_data[continuos_data['AVTOT'] == 0]
# Out:
#        FULLVAL  LTFRONT  LTDEPTH  STORIES  AVLAND  AVTOT  EXLAND  EXTOT  \
# 47           0        0        0      6.0       0      0       0      0
# 59           0       24      100      6.0       0      0       0      0
# 100          0      248      120     66.0       0      0       0      0
# 155          0      174      103      9.0       0      0       0      0
# 211          0       42       98     12.0       0      0       0      0
# ...        ...      ...      ...      ...     ...    ...     ...    ...
# 11553        0        0        0      NaN       0      0       0      0
# 11559        0       10      228      NaN       0      0       0      0
# 11700        0      278      190      NaN       0      0       0      0
# 11839        0       30      271      NaN       0      0       0      0
# 11934        0      106      248      3.0       0      0       0      0
#
#        BLDFRONT  BLDDEPTH  AVLAND2  AVTOT2  EXLAND2  EXTOT2   Latitude  \
# ...

# %%
df['BORO'].unique()
# Out:
# array([1, 2, 3, 4, 5], dtype=int64)

# %%
from scipy import stats

F, p = stats.f_oneway(df[df.BORO==1].FULLVAL,
                      df[df.BORO==2].FULLVAL,
                      df[df.BORO==3].FULLVAL,
                     df[df.BORO==4].FULLVAL,
                     df[df.BORO==5].FULLVAL)

# %%
F
# Out:
# 25.057893823867328

# %%
from sklearn.linear_model import LinearRegression
import numpy as np

# %%
from sklearn.model_selection import train_test_split

train, test = train_test_split(df, test_size=0.2)

# %%
reg = LinearRegression().fit(df[['AVTOT']], df[['FULLVAL']])

# %%
reg.score(train[['AVTOT']], train[['FULLVAL']])
# Out:
# 0.9917149008272769

# %%
reg.coef_
# Out:
# array([[2.21463198]])

# %%
reg.intercept_
# Out:
# array([425749.43516321])

# %%
predicted = reg.predict(test[['AVTOT']])

# %%
diff = predicted - test[['FULLVAL']]

# %%
predicted
# Out:
# array([[ 484747.23121864],
#        [ 478687.99811024],
#        [ 494779.51410644],
#        ...,
#        [1017049.53101201],
#        [2675040.40977655],
#        [ 663545.54445195]])

# %%
# Out:
# array([487330.26021393])

# %%
test[['FULLVAL']]
# Out:
#        FULLVAL
# 8957    444000
# 2000    551000
# 6165    535000
# 4414    111631
# 3133     80292
# ...        ...
# 10275   561000
# 4622   1050000
# 35      593327
# 2103   2257000
# 1634    238610
#
# [2390 rows x 1 columns]

# %%
df_test = test[['FULLVAL', 'AVTOT']]

# %%
df_test
# Out:
#        FULLVAL    AVTOT
# 8957    444000    26640
# 2000    551000    23904
# 6165    535000    31170
# 4414    111631    50234
# 3133     80292    36131
# ...        ...      ...
# 10275   561000    31164
# 4622   1050000    75296
# 35      593327   266997
# 2103   2257000  1015650
# 1634    238610   107375
#
# [2390 rows x 2 columns]

# %%
def ooo(pred) :
    print('row')
    print(pred)

# %%
with np.printoptions(precision=3, suppress=True):
    df_test['pred'] = df_test.apply(lambda row: reg.predict(np.array([row['AVTOT']]).reshape(1, -1))[0][0] , axis=1)
# Out:
# C:\Users\patry\miniconda3\envs\pakmany2\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\patry\miniconda3\envs\pakmany2\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\patry\miniconda3\envs\pakmany2\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\patry\miniconda3\envs\pakmany2\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\patry\miniconda3\envs\pakmany2\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
# ...

# %%
df_test['diff'] = (df_test['FULLVAL'] - df_test['pred'])/df_test['FULLVAL']
# Out:
# C:\Users\patry\AppData\Local\Temp\ipykernel_21996\3061479279.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_test['diff'] = (df_test['FULLVAL'] - df_test['pred'])/df_test['FULLVAL']

# %%
df_test
# Out:
#        FULLVAL    AVTOT          pred      diff
# 8957    444000    26640  4.847472e+05 -0.091773
# 2000    551000    23904  4.786880e+05  0.131238
# 6165    535000    31170  4.947795e+05  0.075178
# 4414    111631    50234  5.369993e+05 -3.810485
# 3133     80292    36131  5.057663e+05 -5.299087
# ...        ...      ...           ...       ...
# 10275   561000    31164  4.947662e+05  0.118064
# 4622   1050000    75296  5.925024e+05  0.435712
# 35      593327   266997  1.017050e+06 -0.714147
# 2103   2257000  1015650  2.675040e+06 -0.185219
# 1634    238610   107375  6.635455e+05 -1.780879
#
# [2390 rows x 4 columns]

# %%
df_test
# Out:
#        FULLVAL    AVTOT          pred      diff
# 8957    444000    26640  4.847472e+05 -0.091773
# 2000    551000    23904  4.786880e+05  0.131238
# 6165    535000    31170  4.947795e+05  0.075178
# 4414    111631    50234  5.369993e+05 -3.810485
# 3133     80292    36131  5.057663e+05 -5.299087
# ...        ...      ...           ...       ...
# 10275   561000    31164  4.947662e+05  0.118064
# 4622   1050000    75296  5.925024e+05  0.435712
# 35      593327   266997  1.017050e+06 -0.714147
# 2103   2257000  1015650  2.675040e+06 -0.185219
# 1634    238610   107375  6.635455e+05 -1.780879
#
# [2390 rows x 4 columns]

# %%
df_test['diff'] = (df_test['FULLVAL'] - df_test['pred'])
# Out:
# C:\Users\patry\AppData\Local\Temp\ipykernel_21996\2221458647.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_test['diff'] = (df_test['FULLVAL'] - df_test['pred'])

# %%
df_test
# Out:
#        FULLVAL    AVTOT          pred           diff
# 8957    444000    26640  4.873303e+05  -43330.260214
# 2000    551000    23904  4.812735e+05   69726.458093
# 6165    535000    31170  4.973584e+05   37641.620660
# 4414    111631    50234  5.395606e+05 -427929.600756
# 3133     80292    36131  5.083406e+05 -428048.608696
# ...        ...      ...           ...            ...
# 10275   561000    31164  4.973451e+05   63654.902937
# 4622   1050000    75296  5.950407e+05  454959.328265
# 35      593327   266997  1.019412e+06 -426084.635211
# 2103   2257000  1015650  2.676714e+06 -419714.387515
# 1634    238610   107375  6.660544e+05 -427444.365650
#
# [2390 rows x 4 columns]

# %%
continuos_data_1 = continuos_data[[continuos_data['TAXCLASS']]]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\miniconda3\envs\pakmany2\lib\site-packages\pandas\core\indexes\base.py:3621, in Index.get_loc(self, key, method, tolerance)
#    3620 try:
# -> 3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
#
# File ~\miniconda3\envs\pakmany2\lib\site-packages\pandas\_libs\index.pyx:136, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\miniconda3\envs\pakmany2\lib\site-packages\pandas\_libs\index.pyx:163, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5198, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5206, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'TAXCLASS'
#
# The above exception was the direct cause of the following exception:
#
# ...
